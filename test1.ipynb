# %%
import pandas as pd

# %%
df = pd.read_csv(r'archive\data_us_pct\AAPL_pct.csv')

# %%
df[:5]
# Out:
#          date      open      high       low     close     volume  \
# 0  2000-01-04  0.820377  0.838376  0.766854  0.776801  512377600
# 1  2000-01-05  0.786273  0.837902  0.780590  0.788168  778321600
# 2  2000-01-06  0.804273  0.810903  0.719961  0.719961  767972800
# 3  2000-01-07  0.731329  0.765433  0.723751  0.754065  460734400
# 4  2000-01-10  0.773011  0.774905  0.718067  0.740802  505064000
#
#    open_pct_change  high_pct_change  low_pct_change  close_pct_change
# 0         3.218112        -1.666672       -0.491676         -8.431009
# 1        -4.157093        -0.056500        1.791216          1.463313
# 2         2.289215        -3.222166       -7.767050         -8.653849
# 3        -9.069510        -5.607400        0.526439          4.736931
# 4         5.699460         1.237539       -0.785407         -1.758794

# %%
df['high']
# Out:
# 0         0.838376
# 1         0.837902
# 2         0.810903
# 3         0.765433
# 4         0.774905
#            ...
# 5972    173.070007
# 5973    174.300003
# 5974    173.630005
# 5975    174.210007
# 5976    175.449997
# Name: high, Length: 5977, dtype: float64

# %%
r = pd.to_datetime(df.date)

# %%
import matplotlib.pyplot as plt

x = [1,2,3]
y= [4, 2, 1]

plt.xlabel

plt.plot(x, y, '+')

plt.annotate("point 1", (2.2,3))

plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
r
# Out:
# 0      2000-01-04
# 1      2000-01-05
# 2      2000-01-06
# 3      2000-01-07
# 4      2000-01-10
#           ...
# 5972   2023-09-29
# 5973   2023-10-02
# 5974   2023-10-03
# 5975   2023-10-04
# 5976   2023-10-05
# Name: date, Length: 5977, dtype: datetime64[ns]

# %%
r.values
# Out:
# array(['2000-01-04T00:00:00.000000000', '2000-01-05T00:00:00.000000000',
#        '2000-01-06T00:00:00.000000000', ...,
#        '2023-10-03T00:00:00.000000000', '2023-10-04T00:00:00.000000000',
#        '2023-10-05T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
t1 = pd.read_csv("sp500_index_pct_spec_s.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t1 = pd.read_csv("sp500_index_pct_spec_s.csv")
#
# File c:\Users\Vincent\.conda\envs\Pytorch_1_11\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\Vincent\.conda\envs\Pytorch_1_11\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
t1
# Out:
#             date          open          high           low         close  \
# 0     2010-01-05  10719.440430  10791.040039  10655.570312  10681.830078
# 1     2010-01-06  10709.549805  10768.610352  10661.169922  10731.450195
# 2     2010-01-07  10742.750000  10774.000000  10636.669922  10681.660156
# 3     2010-01-08  10743.299805  10816.450195  10677.559570  10798.320312
# 4     2010-01-12  10770.349609  10905.389648  10763.679688  10879.139648
# ...          ...           ...           ...           ...           ...
# 2673  2020-12-24  26635.109375  26764.529297  26605.259766  26668.349609
# 2674  2020-12-25  26708.099609  26716.609375  26638.279297  26656.609375
# 2675  2020-12-28  26691.289062  26854.029297  26664.599609  26854.029297
# 2676  2020-12-29  26936.380859  27602.519531  26921.140625  27568.150391
# 2677  2020-12-30  27559.099609  27572.570312  27338.560547  27444.169922
#
#          volume  open_pct_change  high_pct_change  low_pct_change  \
# ...

# %%
abs(t1["open_pct_change"]).mean()
# Out:
# 0.913601500687253
