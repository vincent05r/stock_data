# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob


import pyarrow.dataset as ds
import pyarrow.parquet as pq

from sklearn.preprocessing import StandardScaler

# %%
#save everything into a big dataset


dataset = ds.dataset(r"janestreet\train.parquet", format="parquet", partitioning="hive")

table = dataset.to_table()
df = table.to_pandas()

# df.to_parquet("combined_train_raw.parquet", engine="pyarrow")

# %%
#prep single dataset
df = pd.read_parquet(r"janestreet\train.parquet\partition_id=9\part-0.parquet", engine="pyarrow")

# %% [markdown]
# # preprocessing

# %%
df = pd.read_parquet(r"janestreet\combined_train_raw.parquet", engine='pyarrow')

# %%
df.describe()
# Out:
#             time_id     symbol_id        weight    feature_00    feature_01  \
# count  6.274576e+06  6.274576e+06  6.274576e+06  6.274576e+06  6.274576e+06
# mean   4.835000e+02  1.901404e+01  2.361384e+00  1.873208e+00  2.602108e-02
# std    2.794374e+02  1.124457e+01  1.094003e+00  1.452603e+00  1.133959e+00
# min    0.000000e+00  0.000000e+00  5.324591e-01 -2.561013e+00 -4.274224e+00
# 25%    2.417500e+02  9.000000e+00  1.523484e+00  7.104638e-01 -7.398547e-01
# 50%    4.835000e+02  1.900000e+01  2.162010e+00  2.011877e+00 -2.175932e-02
# 75%    7.252500e+02  2.900000e+01  2.966673e+00  3.047259e+00  7.497100e-01
# max    9.670000e+02  3.800000e+01  7.902302e+00  6.477002e+00  4.709325e+00
#
#          feature_02    feature_03    feature_04    feature_05    feature_06  \
# count  6.274576e+06  6.274576e+06  6.274576e+06  6.274576e+06  6.274576e+06
# mean   1.864772e+00  1.864176e+00 -1.212088e-02 -4.847535e-02 -4.729467e-03
# ...

# %%
df.head()
# Out:
#    time_id  symbol_id    weight  feature_00  feature_01  feature_02  \
# 0        0          0  3.084694    1.153571    1.563784    0.697396
# 1        0          1  2.232906    0.553354    1.730064    0.990195
# 2        0          2  2.404948    1.532503    2.095852    0.919688
# 3        0          3  1.986533    0.647099    1.687460    0.569406
# 4        0          4  2.742601    1.096778    1.551411    0.632113
#
#    feature_03  feature_04  feature_05  feature_06  ...  feature_70  \
# 0    0.756759    2.580965    0.171311    1.126353  ...   -0.959100
# 1    0.611490    2.023031    0.319015    1.183371  ...   -0.960126
# 2    0.583715    2.330047    0.337096    1.262236  ...   -1.219395
# 3    1.061679    2.444131    0.150487    0.896543  ...   -1.398495
# 4    0.368218    2.181873    0.214604    1.194230  ...   -1.123492
#
#    feature_71  feature_72  feature_73  feature_74  feature_75  feature_76  \
# 0    1.284456   -0.275493         NaN         NaN    4.188457    3.666236
# ...

# %%
#drop in place
l = ["date_id", "responder_0", "responder_1", "responder_2", "responder_3", "responder_4", "responder_5", "responder_7", "responder_8"]

df.drop(l, axis=1, inplace=True)

# %%
#drop all nan, drop all na rows
df.dropna(axis=0, inplace=True)

# %%
#saving
df.to_parquet("p10_train_prep_v1_nd_dropna_row.parquet", engine="pyarrow")

# %%
df.head()
# Out:
#       time_id  symbol_id    weight  feature_00  feature_01  feature_02  \
# 2516       68          0  3.084694    0.389057    2.749725    0.718424
# 2517       68          1  2.232906   -0.026452    2.632656    0.187209
# 2518       68          2  2.404948    1.013794    1.809883   -0.376363
# 2519       68          3  1.986533    1.113055    2.298128    0.588921
# 2520       68          4  2.742601    0.429002    2.764029    0.838564
#
#       feature_03  feature_04  feature_05  feature_06  ...  feature_70  \
# 2516    1.256622    0.588988    0.247641   -2.901283  ...    0.048784
# 2517    0.593603    0.481453    0.143793   -2.271466  ...    0.306555
# 2518    0.559347    1.132689    0.188735   -2.102561  ...    0.201693
# 2519    0.045917    0.912620    0.213604   -2.596459  ...    0.202217
# 2520    0.291231    0.691983    0.176078   -1.577382  ...   -0.157728
#
#       feature_71  feature_72  feature_73  feature_74  feature_75  feature_76  \
# ...

# %%
df.describe()
# Out:
#             time_id     symbol_id        weight    feature_00    feature_01  \
# count  5.717524e+06  5.717524e+06  5.717524e+06  5.717524e+06  5.717524e+06
# mean   5.170112e+02  1.880038e+01  2.373997e+00  1.879201e+00 -7.425108e-02
# std    2.596294e+02  1.115287e+01  1.096362e+00  1.443794e+00  1.049744e+00
# min    6.800000e+01  0.000000e+00  5.324591e-01 -2.403379e+00 -4.274224e+00
# 25%    2.920000e+02  9.000000e+00  1.533418e+00  7.276349e-01 -7.779822e-01
# 50%    5.170000e+02  1.900000e+01  2.179573e+00  2.013844e+00 -8.953134e-02
# 75%    7.420000e+02  2.800000e+01  2.979284e+00  3.045248e+00  6.127727e-01
# max    9.670000e+02  3.800000e+01  7.902302e+00  6.477002e+00  4.402467e+00
#
#          feature_02    feature_03    feature_04    feature_05    feature_06  \
# count  5.717524e+06  5.717524e+06  5.717524e+06  5.717524e+06  5.717524e+06
# mean   1.883134e+00  1.878811e+00 -7.541627e-02 -4.386147e-02 -6.740444e-03
# ...
