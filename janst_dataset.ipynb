# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob

from sklearn.preprocessing import StandardScaler

# %%
# Specify the directory containing your parquet files
directory = "janestreet\jane-street-real-time-market-data-forecasting\train.parquet"

# Use glob to find all .parquet files
parquet_files = glob.glob("train.parquet/partition_id=*/part-*.parquet")

# %%
df = pd.read_parquet(r'janestreet\jane-street-real-time-market-data-forecasting\train.parquet\partition_id=6\part-0.parquet')

# %%
parquet_files
# Out:
# []

# %%
df
# Out:
#          date_id  time_id  symbol_id    weight  feature_00  feature_01  \
# 0           1020        0          0  2.679878   -0.151614   -1.218194
# 1           1020        0          1  4.407496   -0.114243   -1.553200
# 2           1020        0          2  2.821721   -0.563401   -1.109032
# 3           1020        0          3  1.700922   -0.499214   -0.807310
# 4           1020        0          4  2.232697    0.271390   -1.067931
# ...          ...      ...        ...       ...         ...         ...
# 6203907     1189      967         34  2.289930    0.739135    0.467176
# 6203908     1189      967         35  1.412874    0.819782    0.135963
# 6203909     1189      967         36  1.500883    0.982752    0.286856
# 6203910     1189      967         37  0.688564    0.935910    0.633613
# 6203911     1189      967         38  2.899886    0.901284    0.242675
#
#          feature_02  feature_03  feature_04  feature_05  ...  feature_78  \
# ...
