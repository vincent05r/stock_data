# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob

from sklearn.preprocessing import StandardScaler

# %%
# # Specify the directory containing your parquet files
# directory = "janestreet\jane-street-real-time-market-data-forecasting\train.parquet"

# # Use glob to find all .parquet files
# parquet_files = glob.glob("train.parquet/partition_id=*/part-*.parquet")

# %%
# df = pd.read_parquet(r'janestreet\jane-street-real-time-market-data-forecasting\train.parquet\partition_id=6\part-0.parquet')

# %%
#save everything into a big dataset

# import pyarrow.dataset as ds
# import pyarrow.parquet as pq

# dataset = ds.dataset(r"janestreet\jane-street-real-time-market-data-forecasting\train.parquet", format="parquet", partitioning="hive")

# table = dataset.to_table()
# df = table.to_pandas()

# df.to_parquet("combined_train_raw.parquet", engine="pyarrow")

# %% [markdown]
# # preprocessing

# %%
df = pd.read_parquet(r"janestreet\combined_train_raw.parquet", engine='pyarrow')

# %%
# df.describe()
# Out:
#             date_id       time_id     symbol_id        weight    feature_00  \
# count  4.712734e+07  4.712734e+07  4.712734e+07  4.712734e+07  4.394529e+07
# mean   1.005479e+03  4.687057e+02  1.810239e+01  2.009441e+00  5.738325e-01
# std    4.451819e+02  2.725187e+02  1.130165e+01  1.152746e+00  1.284554e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  1.499667e-01 -5.794129e+00
# 25%    6.790000e+02  2.330000e+02  9.000000e+00  1.210248e+00 -3.325972e-01
# 50%    1.060000e+03  4.670000e+02  1.700000e+01  1.749686e+00  4.057831e-01
# 75%    1.376000e+03  7.010000e+02  2.800000e+01  2.525645e+00  1.261608e+00
# max    1.698000e+03  9.670000e+02  3.800000e+01  1.024042e+01  6.477002e+00
#
#          feature_01    feature_02    feature_03    feature_04    feature_05  \
# count  4.394529e+07  4.394529e+07  4.394529e+07  4.394529e+07  4.712734e+07
# mean   1.019200e-02  5.731021e-01  5.727453e-01 -8.522313e-04 -3.837985e-02
# ...

# %%
df.head()
# Out:
#    date_id  time_id  symbol_id    weight  feature_00  feature_01  feature_02  \
# 0        0        0          1  3.889038         NaN         NaN         NaN
# 1        0        0          7  1.370613         NaN         NaN         NaN
# 2        0        0          9  2.285698         NaN         NaN         NaN
# 3        0        0         10  0.690606         NaN         NaN         NaN
# 4        0        0         14  0.440570         NaN         NaN         NaN
#
#    feature_03  feature_04  feature_05  ...  feature_70  feature_71  \
# 0         NaN         NaN    0.851033  ...   -1.022690    0.152241
# 1         NaN         NaN    0.676961  ...   -1.052685   -0.393726
# 2         NaN         NaN    1.056285  ...   -0.863230   -0.241892
# 3         NaN         NaN    1.139366  ...   -0.530602    4.765215
# 4         NaN         NaN    0.955200  ...   -1.141761    0.099631
#
#    feature_72  feature_73  feature_74  feature_75  feature_76  feature_77  \
# ...

# %%
#drop in place
l = ["responder_0", "responder_1", "responder_2", "responder_3", "responder_4", "responder_5", "responder_7", "responder_8", "partition_id"]

df.drop(l, axis=1, inplace=True)

# %%
df.drop("date_id", axis=1, inplace=True)

# %%
#saving
df.to_parquet("combined_train_prep_v1_nd.parquet", engine="pyarrow")

# %%
df.head()
# Out:
#    time_id  symbol_id    weight  feature_00  feature_01  feature_02  \
# 0        0          1  3.889038         NaN         NaN         NaN
# 1        0          7  1.370613         NaN         NaN         NaN
# 2        0          9  2.285698         NaN         NaN         NaN
# 3        0         10  0.690606         NaN         NaN         NaN
# 4        0         14  0.440570         NaN         NaN         NaN
#
#    feature_03  feature_04  feature_05  feature_06  ...  feature_70  \
# 0         NaN         NaN    0.851033    0.242971  ...   -1.022690
# 1         NaN         NaN    0.676961    0.151984  ...   -1.052685
# 2         NaN         NaN    1.056285    0.187227  ...   -0.863230
# 3         NaN         NaN    1.139366    0.273328  ...   -0.530602
# 4         NaN         NaN    0.955200    0.262404  ...   -1.141761
#
#    feature_71  feature_72  feature_73  feature_74  feature_75  feature_76  \
# 0    0.152241   -0.659864         NaN         NaN   -0.261412   -0.211486
# ...
