# %%
import yfinance as yf
import pandas as pd
from df_preprocessing import convert_to_pct
import os

import time
import datetime

# %%
dva_spec = False

# %%
df = pd.read_csv('list.csv')

# %%
l = df['Symbol'].tolist()

# %%
print(l)
# Out:
# ['AAPL', 'NVDA', 'MSFT', 'AMZN', 'META', 'GOOGL', 'TSLA', 'BRK.B', 'GOOG', 'AVGO', 'JPM', 'LLY', 'UNH', 'XOM', 'V', 'MA', 'COST', 'HD', 'PG', 'JNJ', 'WMT', 'NFLX', 'BAC', 'CRM', 'ORCL', 'ABBV', 'CVX', 'WFC', 'MRK', 'KO', 'CSCO', 'AMD', 'ADBE', 'ACN', 'PEP', 'LIN', 'MCD', 'NOW', 'DIS', 'PM', 'ABT', 'GE', 'IBM', 'TMO', 'INTU', 'TXN', 'ISRG', 'CAT', 'GS', 'QCOM', 'VZ', 'BKNG', 'MS', 'CMCSA', 'T', 'SPGI', 'AXP', 'RTX', 'NEE', 'LOW', 'PGR', 'AMGN', 'HON', 'DHR', 'BLK', 'UBER', 'UNP', 'ETN', 'AMAT', 'PFE', 'TJX', 'SYK', 'BSX', 'COP', 'BX', 'C', 'PANW', 'PLTR', 'FI', 'SCHW', 'ADP', 'VRTX', 'TMUS', 'BMY', 'SBUX', 'LMT', 'MDT', 'GILD', 'MMC', 'CB', 'MU', 'PLD', 'INTC', 'BA', 'ADI', 'DE', 'KKR', 'UPS', 'SO', 'MO', 'ANET', 'ELV', 'AMT', 'TT', 'LRCX', 'ICE', 'CI', 'NKE', 'GEV', 'PH', 'DUK', 'SHW', 'PYPL', 'EQIX', 'MDLZ', 'APH', 'KLAC', 'AON', 'PNC', 'CME', 'MSI', 'REGN', 'CDNS', 'CMG', 'SNPS', 'ZTS', 'MCK', 'WM', 'WELL', 'CRWD', 'USB', 'EOG', 'CL', 'CTAS', 'EMR', 'MCO', 'GD', 'ITW', 'APD', 'TGT', 'CEG', 'MMM', 'ORLY', 'WMB', 'CVS', 'TDG', 'COF', 'CSX', 'NOC', 'FDX', 'MAR', 'OKE', 'ADSK', 'BDX', 'AJG', 'GM', 'TFC', 'FCX', 'HCA', 'ECL', 'CARR', 'SLB', 'HLT', 'TRV', 'NSC', 'ROP', 'SRE', 'PCAR', 'FTNT', 'ABNB', 'BK', 'AFL', 'DLR', 'NXPI', 'JCI', 'FICO', 'AMP', 'URI', 'SPG', 'PSX', 'RCL', 'AZO', 'KMI', 'MPC', 'PSA', 'ALL', 'GWW', 'AEP', 'VST', 'CMI', 'CPRT', 'O', 'AIG', 'MET', 'NEM', 'D', 'PWR', 'FIS', 'DHI', 'ROST', 'FAST', 'MSCI', 'LHX', 'HWM', 'VLO', 'KMB', 'CCI', 'PAYX', 'KVUE', 'PRU', 'TEL', 'PCG', 'AME', 'PEG', 'F', 'TRGP', 'DFS', 'AXON', 'BKR', 'RSG', 'COR', 'EW', 'IR', 'HES', 'LEN', 'DAL', 'OTIS', 'ODFL', 'IT', 'CBRE', 'VRSK', 'CTVA', 'EA', 'EXC', 'DELL', 'XEL', 'KR', 'CTSH', 'GEHC', 'YUM', 'MNST', 'CHTR', 'STZ', 'SYY', 'A', 'VMC', 'HPQ', 'ACGL', 'MTB', 'GLW', 'LULU', 'MLM', 'RMD', 'KDP', 'MCHP', 'GIS', 'NUE', 'EXR', 'HIG', 'IDXX', 'OXY', 'WAB', 'DD', 'FANG', 'IRM', 'VICI', 'ED', 'IQV', 'NDAQ', 'HUM', 'AVB', 'EIX', 'GRMN', 'ROK', 'ETR', 'WTW', 'FITB', 'WEC', 'DOW', 'CNC', 'DXCM', 'EFX', 'RJF', 'CSGP', 'EBAY', 'TSCO', 'TTWO', 'XYL', 'UAL', 'GPN', 'ANSS', 'CAH', 'PPG', 'STT', 'MPWR', 'ON', 'HPE', 'DOV', 'KHC', 'NVR', 'CHD', 'DECK', 'HAL', 'PHM', 'AWK', 'BR', 'KEYS', 'TROW', 'VTR', 'SW', 'EQT', 'FTV', 'GDDY', 'BRO', 'HBAN', 'TYL', 'VLTO', 'EQR', 'CPAY', 'SYF', 'ADM', 'HSY', 'PPL', 'DTE', 'MTD', 'CCL', 'AEE', 'NTAP', 'DVN', 'RF', 'HUBB', 'SBAC', 'CDW', 'CINF', 'ZBH', 'BIIB', 'ATO', 'PTC', 'WY', 'EXPE', 'WST', 'ES', 'IFF', 'NTRS', 'TDY', 'LYB', 'K', 'CBOE', 'LDOS', 'FE', 'STE', 'PKG', 'WBD', 'WAT', 'WDC', 'CLX', 'FSLR', 'CFG', 'BLDR', 'LYV', 'CMS', 'STX', 'CNP', 'STLD', 'IP', 'LH', 'ZBRA', 'COO', 'DRI', 'INVH', 'ESS', 'LUV', 'CTRA', 'NRG', 'OMC', 'SNA', 'MKC', 'MAA', 'BALL', 'FDS', 'TSN', 'PFG', 'HOLX', 'WRB', 'PODD', 'DGX', 'KEY', 'J', 'PNR', 'BBY', 'LVS', 'GPC', 'IEX', 'MOH', 'TRMB', 'TER', 'EXPD', 'DG', 'KIM', 'ULTA', 'BAX', 'MAS', 'NI', 'ARE', 'MRO', 'EG', 'ALGN', 'AVY', 'GEN', 'LNT', 'CF', 'TXT', 'DPZ', 'VTRS', 'L', 'EL', 'VRSN', 'JBHT', 'DOC', 'EVRG', 'AMCR', 'JBL', 'ROL', 'APTV', 'FFIV', 'POOL', 'NDSN', 'RVTY', 'DLTR', 'SWKS', 'MRNA', 'UDR', 'SWK', 'EPAM', 'AKAM', 'TPR', 'BG', 'CHRW', 'CPT', 'CAG', 'JKHY', 'INCY', 'HST', 'ALB', 'EMN', 'ALLE', 'REG', 'KMX', 'DAY', 'UHS', 'SJM', 'JNPR', 'AIZ', 'NCLH', 'BXP', 'LW', 'GNRC', 'TAP', 'SMCI', 'NWSA', 'PAYC', 'CTLT', 'TECH', 'PNW', 'IPG', 'ERIE', 'FOXA', 'MKTX', 'LKQ', 'GL', 'AES', 'CRL', 'HSIC', 'SOLV', 'TFX', 'AOS', 'MGM', 'CPB', 'HRL', 'FRT', 'WYNN', 'ENPH', 'RL', 'APA', 'MOS', 'HAS', 'CE', 'CZR', 'MTCH', 'IVZ', 'BWA', 'HII', 'BF.B', 'DVA', 'MHK', 'FMC', 'BEN', 'PARA', 'QRVO', 'WBA', 'FOX', 'NWS', 'AMTM']

# %%
acl_18_ext_2016 = l.copy()

# %% [markdown]
# # stock list data

# %%
#daily interval
stock_ticker_dict = {}

for stock_name in acl_18_ext_2016:


    start_date = datetime.datetime.strptime('2024-11-12', '%Y-%m-%d')
    end_date = start_date + datetime.timedelta(days=6)

    num_iterations = 5  # For example, you can set the number of iterations you want

    data_frames = [] # List to store each DataFrame

    c_ticker = yf.Ticker(stock_name)

    for _ in range(num_iterations):

        # Convert dates to string format required by the history function
        start_str = start_date.strftime("%Y-%m-%d")
        end_str = end_date.strftime("%Y-%m-%d")

        
        # Fetch data
        c_data = c_ticker.history(start=start_str, end=end_str, interval='1m')
        
        # Add the DataFrame to the list
        data_frames.append(c_data)
        
        # Increment the dates by 7 days
        start_date += datetime.timedelta(days=7)
        end_date += datetime.timedelta(days=7)

        time.sleep(0.1)
        

    merged_data = pd.concat(data_frames)

    stock_ticker_dict[stock_name] = [c_ticker, merged_data]
# Out:
# BRK.B: No timezone found, symbol may be delisted
# BRK.B: No timezone found, symbol may be delisted
# BRK.B: No timezone found, symbol may be delisted
# BRK.B: No timezone found, symbol may be delisted
# BRK.B: No timezone found, symbol may be delisted
# CAH: No price data found, symbol may be delisted (1m 2024-11-19 -> 2024-11-25)
# MRO: No price data found, symbol may be delisted (1m 2024-11-26 -> 2024-12-02)
# MRO: No price data found, symbol may be delisted (1m 2024-12-03 -> 2024-12-09)
# MRO: No price data found, symbol may be delisted (1m 2024-12-10 -> 2024-12-16)
# BF.B: No price data found, symbol may be delisted (1m 2024-11-12 -> 2024-11-18)
# BF.B: No price data found, symbol may be delisted (1m 2024-11-19 -> 2024-11-25)
# BF.B: No price data found, symbol may be delisted (1m 2024-11-26 -> 2024-12-02)
# BF.B: No price data found, symbol may be delisted (1m 2024-12-03 -> 2024-12-09)
# BF.B: No price data found, symbol may be delisted (1m 2024-12-10 -> 2024-12-16)

# %%
stock_ticker_dict['AAPL'][1].head()
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-11-12 09:30:00-05:00  224.630005  225.039993  224.500000  224.714996
# 2024-11-12 09:31:00-05:00  224.699997  224.771301  224.279999  224.320007
# 2024-11-12 09:32:00-05:00  224.320007  224.789993  224.305603  224.429993
# 2024-11-12 09:33:00-05:00  224.440002  224.539993  223.910004  223.964996
# 2024-11-12 09:34:00-05:00  223.979996  224.160004  223.770004  223.901398
#
#                             Volume  Dividends  Stock Splits
# Datetime
# 2024-11-12 09:30:00-05:00  1444824        0.0           0.0
# 2024-11-12 09:31:00-05:00   140920        0.0           0.0
# 2024-11-12 09:32:00-05:00   185809        0.0           0.0
# 2024-11-12 09:33:00-05:00   175410        0.0           0.0
# 2024-11-12 09:34:00-05:00   162434        0.0           0.0

# %%
# stock_ticker_dict['ABB'][1].empty

#check empty

temp_l = []

for stock_name in acl_18_ext_2016:
    if not stock_ticker_dict[stock_name][1].empty:
        temp_l.append(stock_name)

acl_18_ext_2016 = temp_l

# %%
len(acl_18_ext_2016)
# Out:
# 501

# %%
stock_ticker_dict['AAPL'][1].head()
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-11-12 09:30:00-05:00  224.630005  225.039993  224.500000  224.714996
# 2024-11-12 09:31:00-05:00  224.699997  224.771301  224.279999  224.320007
# 2024-11-12 09:32:00-05:00  224.320007  224.789993  224.305603  224.429993
# 2024-11-12 09:33:00-05:00  224.440002  224.539993  223.910004  223.964996
# 2024-11-12 09:34:00-05:00  223.979996  224.160004  223.770004  223.901398
#
#                             Volume  Dividends  Stock Splits
# Datetime
# 2024-11-12 09:30:00-05:00  1444824        0.0           0.0
# 2024-11-12 09:31:00-05:00   140920        0.0           0.0
# 2024-11-12 09:32:00-05:00   185809        0.0           0.0
# 2024-11-12 09:33:00-05:00   175410        0.0           0.0
# 2024-11-12 09:34:00-05:00   162434        0.0           0.0

# %%
for stock_name in acl_18_ext_2016:



    pct_list = ['open', 'high', 'low', 'close']
    
    #original
    stock_ticker_dict[stock_name][1].drop(['Dividends', 'Stock Splits'], axis=1, inplace=True)
    stock_ticker_dict[stock_name][1] = stock_ticker_dict[stock_name][1].reset_index()
    stock_ticker_dict[stock_name][1] = stock_ticker_dict[stock_name][1].rename(columns=lambda x: x.lower())

    #datetime info change
    #temp_dt = pd.to_datetime(stock_ticker_dict[stock_name][1].date)
    #stock_ticker_dict[stock_name][1]['datetime'] = temp_dt.dt.strftime('%Y-%m-%d')
    

    #pct
    temp_data = stock_ticker_dict[stock_name][1].copy()
    convert_to_pct(temp_data, pct_list, drop_NA=True, drop_inplace=True)
    # temp_data = temp_data.reset_index().drop('index', axis=1)
    temp_data = temp_data.rename(columns={'index':'date'})

    stock_ticker_dict[stock_name].append(temp_data)

    #add the target
    if dva_spec:
        stock_ticker_dict[stock_name][2]['target'] = stock_ticker_dict[stock_name][1]['close'].copy()
        pct_list.append('target')

# %%
# #test
# dtx = sp_500_data[sp_500_data['index_date'].isin(stock_ticker_dict['AAPL'][2]['date'])].reset_index().drop('index', axis=1)
# dtx_m = pd.concat([stock_ticker_dict['AAPL'][2], dtx], axis=1, join='outer')
# # dtx = dtx.rename(columns={'index_date':'date'})
# # dtx.date = pd.to_datetime(dtx.date)
# # stock_ticker_dict['AAPL'][2].date = pd.to_datetime(stock_ticker_dict['AAPL'][2].date)
# # dtx_m = pd.merge(stock_ticker_dict['AAPL'][2], index_match_df, on='date', how='left')

# %%
# display(dtx[-10:])
# display(dtx_m)
# acl_18_ext[0]

# %%
display(stock_ticker_dict[acl_18_ext_2016[0]][2])
# Out:
#                       datetime   volume  open_pct_change  high_pct_change  \
# 1    2024-11-12 09:31:00-05:00   140920         0.031159        -0.119397
# 2    2024-11-12 09:32:00-05:00   185809        -0.169110         0.008316
# 3    2024-11-12 09:33:00-05:00   175410         0.053493        -0.111215
# 4    2024-11-12 09:34:00-05:00   162434        -0.204958        -0.169230
# 5    2024-11-12 09:35:00-05:00   174387        -0.033484        -0.053579
# ...                        ...      ...              ...              ...
# 6414 2024-12-11 15:55:00-05:00   348441        -0.032408        -0.012146
# 6415 2024-12-11 15:56:00-05:00   375808        -0.005064        -0.064789
# 6416 2024-12-11 15:57:00-05:00   248206        -0.080033        -0.074958
# 6417 2024-12-11 15:58:00-05:00   331989        -0.043721        -0.046634
# 6418 2024-12-11 15:59:00-05:00  1203327         0.011280         0.008115
#
#       low_pct_change  close_pct_change
# 1          -0.097996         -0.175773
# 2           0.011416          0.049031
# 3          -0.176366         -0.207190
# 4          -0.062525         -0.028397
# 5          -0.035752          0.032562
# ...              ...               ...
# 6414       -0.002028         -0.014022
# 6415       -0.117525         -0.085668
# 6416       -0.004061         -0.034881
# 6417        0.000000          0.010587
# 6418       -0.077052         -0.024384
#
# [6418 rows x 6 columns]

# %%
save_raw = False
save_pct = True
save_pct_index = False


#export csv
folder_raw = 'EcmP_stock_L_2016_24_dva_spec/'
folder_pct = 'hftdata/hft_m_2411'
folder_pct_index = 'stock_us_pctindex/'

if not os.path.exists(folder_raw) and save_raw:
    os.makedirs(folder_raw)

if not os.path.exists(folder_pct) and save_pct:
    os.makedirs(folder_pct)

if not os.path.exists(folder_pct_index) and save_pct_index:
    os.makedirs(folder_pct_index)

for stock_name in stock_ticker_dict.keys():

    if len(stock_ticker_dict[stock_name][1]) < 5:
        print(f"skip stock {stock_name}, insufficient data with a len of {len(stock_ticker_dict[stock_name][1])}")
        continue

    if save_raw:
        file_ori = folder_raw + stock_name+'.csv'
        stock_ticker_dict[stock_name][1].to_csv(file_ori, index=False)

    if save_pct:
        file_pct = folder_pct + stock_name+'_pct.csv'
        stock_ticker_dict[stock_name][2].to_csv(file_pct, index=False)

    if save_pct_index:
        file_pct_index = folder_pct_index + stock_name + '_pct_index.csv'
        stock_ticker_dict[stock_name][3].to_csv(file_pct_index, index=False)
# Out:
# skip stock BRK.B, insufficient data with a len of 0
# skip stock BF.B, insufficient data with a len of 0

# %% [markdown]
# 1) apple
# 2) Lockheed Martin
# 3) Boeing
# 4) AT&T
# 5) Netflix
# 6) tsmc
# 7) asml
# 8) intel
# 9) nvidia
# 10) amd
# 11. HLX
# 12. XPOF
# 13. WGO
# 14. MLTX
# 15. WW
# 16. INSW
# 17. MLTX
# 18. msft
# 19. intc
# 20.  jpmc
# 21. amzn
# 22. tsla
